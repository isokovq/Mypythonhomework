# %%
import pandas as pd
import numpy as np
import sqlite3
import datetime

# %%
df = pd.read_csv(r"C:\Users\Administrator\Desktop\DAtA SEA\python-homework\lesson-18\homework\task\tackoverflow_qa.csv")
df['creationdate'] = pd.to_datetime(df['creationdate'])
df
# Out:
#             id        creationdate  score  viewcount  \
# 0       332289 2008-12-01 21:24:44   3184    5962784
# 1      2051744 2010-01-12 19:31:47    420     587728
# 2      2225995 2010-02-09 00:51:38     51      59922
# 3      5486226 2011-03-30 12:26:50      7       6393
# 4      5515021 2011-04-01 14:50:44     10      13744
# ...        ...                 ...    ...        ...
# 9458  27627397 2014-12-23 20:15:38      0        611
# 9459  27693117 2014-12-29 17:13:03      0       2893
# 9460  27673337 2014-12-28 02:53:36      3       2125
# 9461  27712500 2014-12-30 21:01:45      2        266
# 9462  27712482 2014-12-30 20:59:58      0        183
#
#                                                   title  answercount  \
# 0     How do I change the size of figures drawn with...           14
# 1                         How to invert the x or y axis           10
# 2                  How can I create stacked line graph?            4
# ...

# %%
df[df['creationdate'] < pd.Timestamp('2014-01-01')]
# Out:
#             id        creationdate  score  viewcount  \
# 0       332289 2008-12-01 21:24:44   3184    5962784
# 1      2051744 2010-01-12 19:31:47    420     587728
# 2      2225995 2010-02-09 00:51:38     51      59922
# 3      5486226 2011-03-30 12:26:50      7       6393
# 4      5515021 2011-04-01 14:50:44     10      13744
# ...        ...                 ...    ...        ...
# 4597  20788932 2013-12-26 17:47:41      0       1928
# 4598  20845213 2013-12-30 18:24:25    731     771804
# 4604  20789976 2013-12-26 19:14:54      1        916
# 4608  20819702 2013-12-28 21:41:31      5       6792
# 4757  17600430 2013-07-11 18:08:12      2       1306
#
#                                                   title  answercount  \
# 0     How do I change the size of figures drawn with...           14
# 1                         How to invert the x or y axis           10
# 2                  How can I create stacked line graph?            4
# ...

# %%
df[df['score'] > 50]
# Out:
#             id        creationdate  score  viewcount  \
# 0       332289 2008-12-01 21:24:44   3184    5962784
# 1      2051744 2010-01-12 19:31:47    420     587728
# 2      2225995 2010-02-09 00:51:38     51      59922
# 7      6541123 2011-06-30 21:09:11    550     832218
# 12     7837722 2011-10-20 14:46:14    401     658113
# ...        ...                 ...    ...        ...
# 9264  26053849 2014-09-26 07:04:13     94     161773
# 9343  26646191 2014-10-30 06:10:51    103     228729
# 9369  26640145 2014-10-29 20:34:16     71     174274
# 9373  27060098 2014-11-21 11:17:27    126     402220
# 9414  27673231 2014-12-28 02:22:27    360     348337
#
#                                                   title  answercount  \
# 0     How do I change the size of figures drawn with...           14
# 1                         How to invert the x or y axis           10
# 2                  How can I create stacked line graph?            4
# ...

# %%
df[(df['score'] > 50) & (df['score']<100)]
# Out:
#             id        creationdate  score  viewcount  \
# 2      2225995 2010-02-09 00:51:38     51      59922
# 42     9787853 2012-03-20 13:36:09     80      62070
# 65    10065051 2012-04-08 18:01:13     98     126795
# 86    10457584 2012-05-05 00:00:12     87     137928
# 98    10591000 2012-05-14 21:01:58     80     130343
# ...        ...                 ...    ...        ...
# 9234  27159189 2014-11-26 21:28:37     97     383573
# 9241  25980018 2014-09-22 17:41:11     53      54477
# 9261  26347412 2014-10-13 19:24:44     76     146759
# 9264  26053849 2014-09-26 07:04:13     94     161773
# 9369  26640145 2014-10-29 20:34:16     71     174274
#
#                                                   title  answercount  \
# 2                  How can I create stacked line graph?            4
# 42               join or merge with overwrite in pandas            4
# 65               python-pandas and databases like mysql           14
# ...

# %%
df[df['ans_name'] == 'Scott Boston']
# Out:
#             id        creationdate  score  viewcount  \
# 5392  24290297 2014-06-18 16:06:35     90      95248
#
#                                                   title  answercount  \
# 5392  Pandas dataframe with multiindex column - merg...            6
#
#       commentcount  favoritecount quest_name  quest_rep      ans_name  \
# 5392             1            0.0    Zhubarb    11581.0  Scott Boston
#
#        ans_rep
# 5392  149017.0

# %%
df[5393:5398]
# Out:
#             id        creationdate  score  viewcount  \
# 5393  24203136 2014-06-13 10:23:37      1       2084
# 5394  22231592 2014-03-06 17:24:23    169     647849
# 5395  22451240 2014-03-17 09:55:25      1       1469
# 5396  23618585 2014-05-12 20:49:43      3       5748
# 5397  23717206 2014-05-17 23:43:21      5       2237
#
#                                                   title  answercount  \
# 5393  Pandas Dataframe GroupBy - Displaying Group St...            1
# 5394       Pandas: change data type of Series to String           11
# 5395               Optimising Pandas multi-index lookup            1
# 5396  Best way to set a multiindex on a pandas dataf...            1
# 5397           Casting numpy dtypes to pandas DataFrame            0
#
#       commentcount  favoritecount quest_name  quest_rep     ans_name   ans_rep
# 5393             0            NaN    Zhubarb    11581.0   Matti John   19657.0
# ...

# %%
df[(df['creationdate']>pd.Timestamp('2014-03-01')) & (df['creationdate']<pd.Timestamp('2014-10-31')) & (df['ans_name'] == 'Unutbu') & (df['score']<5)]
# Out:
# Empty DataFrame
# Columns: [id, creationdate, score, viewcount, title, answercount, commentcount, favoritecount, quest_name, quest_rep, ans_name, ans_rep]
# Index: []

# %%
df[(df['score']>5) &(df['score']<10) | (df['viewcount']>10000)]
# Out:
#             id        creationdate  score  viewcount  \
# 0       332289 2008-12-01 21:24:44   3184    5962784
# 1      2051744 2010-01-12 19:31:47    420     587728
# 2      2225995 2010-02-09 00:51:38     51      59922
# 3      5486226 2011-03-30 12:26:50      7       6393
# 4      5515021 2011-04-01 14:50:44     10      13744
# ...        ...                 ...    ...        ...
# 9401  26921943 2014-11-14 02:27:53     28      59154
# 9404  27524169 2014-12-17 11:05:47      5      15767
# 9406  27020707 2014-11-19 15:32:13      6      20062
# 9414  27673231 2014-12-28 02:22:27    360     348337
# 9427  27718650 2014-12-31 08:57:47     15      17818
#
#                                                   title  answercount  \
# 0     How do I change the size of figures drawn with...           14
# 1                         How to invert the x or y axis           10
# 2                  How can I create stacked line graph?            4
# ...

# %%
df[df['ans_name'] != 'Scott Boston']
# Out:
#             id        creationdate  score  viewcount  \
# 0       332289 2008-12-01 21:24:44   3184    5962784
# 1      2051744 2010-01-12 19:31:47    420     587728
# 2      2225995 2010-02-09 00:51:38     51      59922
# 3      5486226 2011-03-30 12:26:50      7       6393
# 4      5515021 2011-04-01 14:50:44     10      13744
# ...        ...                 ...    ...        ...
# 9458  27627397 2014-12-23 20:15:38      0        611
# 9459  27693117 2014-12-29 17:13:03      0       2893
# 9460  27673337 2014-12-28 02:53:36      3       2125
# 9461  27712500 2014-12-30 21:01:45      2        266
# 9462  27712482 2014-12-30 20:59:58      0        183
#
#                                                   title  answercount  \
# 0     How do I change the size of figures drawn with...           14
# 1                         How to invert the x or y axis           10
# 2                  How can I create stacked line graph?            4
# ...

# %%
tit = pd.read_csv(r"C:\Users\Administrator\Desktop\DAtA SEA\python-homework\lesson-18\homework\task\titanic.csv")
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit[(tit['Pclass'] ==1) & (tit['Sex'] == 'female') &(tit['Age']>20) & (tit['Age']<30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 88            89         1       1
# 151          152         1       1
# 290          291         1       1
# 310          311         1       1
# 341          342         1       1
# 356          357         1       1
# 369          370         1       1
# 393          394         1       1
# 498          499         0       1
# 539          540         1       1
# 627          628         1       1
# 641          642         1       1
# 708          709         1       1
# 710          711         1       1
# 730          731         1       1
# 742          743         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 88                         Fortune, Miss. Mabel Helen  female  23.0      3
# 151                 Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 290                      Barber, Miss. Ellen "Nellie"  female  26.0      0
# ...

# %%
tit[tit['Fare']>100]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
tit[(tit['Survived'] == 1) & (tit['SibSp'] ==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit[(tit['Embarked'] == 'C') & (tit['Fare']>50)]['Name']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 34                               Meyer, Mr. Edgar Joseph
# 52              Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 54                        Ostby, Mr. Engelhart Cornelius
#                              ...
# 742                Ryerson, Miss. Susan Parker "Suzette"
# 789                             Guggenheim, Mr. Benjamin
# 835                          Compton, Miss. Sara Rebecca
# 849         Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# Name: Name, Length: 61, dtype: object

# %%
tit[(tit['SibSp'] > 0) & (tit['Parch'] > 0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 24            25         0       3
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 869          870         1       3
# 871          872         1       1
# 888          889         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 16                               Rice, Master. Eugene    male   2.0      4
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# ..                                                ...     ...   ...    ...
# ...

# %%
tit[(tit['Survived']==0) & (tit['Age']<15)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 111          112         0       3                     Zabour, Miss. Hileni
# 119          120         0       3        Andersson, Miss. Ellis Anna Maria
# 147          148         0       3         Ford, Miss. Robina Maggie "Ruby"
# 164          165         0       3             Panula, Master. Eino Viljami
# ...

# %%
tit[(tit['Cabin'].notnull()) & (tit['Fare']>200)]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 438          439         0       1
# 527          528         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 118                           Baxter, Mr. Quigg Edmond    male  24.0      0
# ...

# %%
tit[tit['PassengerId'].isin([i for i in range(1,100001,2)])] #or
tit[tit['PassengerId'] % 2 == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit[tit['Ticket'].isin(tit['Ticket'].unique())]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit[(tit['Pclass'] == 1) & (tit['Sex'] == 'female') & (tit['Name'].str.contains('Miss'))]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 11            12         1       1               Bonnell, Miss. Elizabeth
# 61            62         1       1                    Icard, Miss. Amelie
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 136          137         1       1           Newsom, Miss. Helen Monypeny
# 177          178         0       1             Isham, Miss. Ann Elizabeth
# 195          196         1       1                   Lurette, Miss. Elise
# 215          216         1       1                Newell, Miss. Madeleine
# 218          219         1       1                  Bazzani, Miss. Albina
# 257          258         1       1                   Cherry, Miss. Gladys
# 258          259         1       1                       Ward, Miss. Anna
# 269          270         1       1                 Bissette, Miss. Amelia
# 275          276         1       1      Andrews, Miss. Kornelia Theodosia
# ...
